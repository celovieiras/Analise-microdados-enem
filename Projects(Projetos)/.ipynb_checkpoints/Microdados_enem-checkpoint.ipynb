# %% [markdown]
# # Análise de microdados do ENEM 2021

# %% [markdown]
# **Notebook seguindo passo a passo da playlist de análise de dados em Python do canal Programação Dinâmica, no youtube.**

# %%
import pandas as pd
import matplotlib as matpl

# %%
microdadosENEM = pd.read_csv("Datasets/DADOS/MICRODADOS_ENEM_2018.csv", sep=";", encoding='cp1252') #, engine='python')

# %%
microdadosENEM.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  180007186625    2018                2       F              0.0
# 1  180007186627    2018                3       F              0.0
# 2  180007186628    2018                3       M              0.0
# 3  180007186629    2018                2       F              0.0
# 4  180007186631    2018               11       F              0.0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            4                 1                2                0          4
# 1            4                 1                1                1          1
# 2            0                 1                2                0          2
# 3            3                 1                2                0          4
# 4            5                 1                1                6          1
#
#    ...  Q018  Q019  Q020 Q021  Q022 Q023  Q024  Q025  Q026  Q027
# ...

# %%
microdadosENEM
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        180007186625    2018                2       F              0.0
# 1        180007186627    2018                3       F              0.0
# 2        180007186628    2018                3       M              0.0
# 3        180007186629    2018                2       F              0.0
# 4        180007186631    2018               11       F              0.0
# ...               ...     ...              ...     ...              ...
# 5513728  180014002713    2018               11       F              0.0
# 5513729  180014002715    2018                4       F              0.0
# 5513730  180014002716    2018                5       M              0.0
# 5513731  180014002721    2018                5       F              0.0
# 5513732  180014002722    2018               11       M              1.0
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
microdadosENEM.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasselecENEM = ['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
                                           'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
                                           'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
                                           'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
                                           'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
                                           'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
                                           'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
                                           'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
                                           'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
                                           'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
                                           'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
                                           'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
                                           'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
                                           'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
                                           'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
                                            'NU_NOTA_REDACAO']

# %%
MicrodadosENEMSelec = microdadosENEM.filter(items=colunasselecENEM)

# %%
MicrodadosENEMSelec.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  180007186625    2018                2       F              0.0
# 1  180007186627    2018                3       F              0.0
# 2  180007186628    2018                3       M              0.0
# 3  180007186629    2018                2       F              0.0
# 4  180007186631    2018               11       F              0.0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            4                 1                2                0          4
# 1            4                 1                1                1          1
# 2            0                 1                2                0          2
# 3            3                 1                2                0          4
# 4            5                 1                1                6          1
#
#    ...                                 TX_GABARITO_CH  \
# ...

# %% [markdown]
# Pegando só 100 linhas

# %%
micro_ENEMSelec = MicrodadosENEMSelec[0:10]

# %%
microlastFifty = microdadosENEM.tail(50)

# %%
microdados50 = microdadosENEM[0:50]

# %%
micro_ENEMSelec
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  180007186625    2018                2       F              0.0
# 1  180007186627    2018                3       F              0.0
# 2  180007186628    2018                3       M              0.0
# 3  180007186629    2018                2       F              0.0
# 4  180007186631    2018               11       F              0.0
# 5  180007186632    2018                2       F              0.0
# 6  180007186633    2018               13       F              1.0
# 7  180007186634    2018               12       F              0.0
# 8  180007186635    2018                4       F              0.0
# 9  180007186636    2018               12       M              0.0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            4                 1                2                0          4
# 1            4                 1                1                1          1
# ...

# %%
Nota_red = MicrodadosENEMSelec['NU_NOTA_REDACAO']

# %%
Nota_red
# Out:
# 0          360.0
# 1          420.0
# 2          600.0
# 3          800.0
# 4          500.0
#            ...
# 5513728    360.0
# 5513729      NaN
# 5513730    420.0
# 5513731    720.0
# 5513732    340.0
# Name: NU_NOTA_REDACAO, Length: 5513733, dtype: float64

# %%
Nota_red.value_counts().sort_index()
# Out:
# 0.0       111990
# 40.0          76
# 60.0         134
# 80.0         199
# 100.0        206
# 120.0        591
# 140.0        758
# 160.0       2027
# 180.0       3083
# 200.0       8512
# 220.0      14504
# 240.0      36625
# 260.0      53431
# 280.0     101930
# 300.0     120825
# 320.0     198868
# 340.0     214241
# 360.0     285814
# 380.0     140419
# 400.0     134555
# 420.0      71158
# 440.0     108534
# 460.0      95327
# 480.0     147411
# 500.0     134829
# 520.0     199782
# 540.0     184333
# 560.0     238997
# 580.0     188814
# 600.0     210363
# 620.0     139080
# 640.0     151013
# 660.0      91867
# 680.0     108886
# 700.0      70557
# 720.0      86064
# 740.0      56216
# 760.0      70520
# 780.0      46120
# 800.0      57349
# 820.0      37098
# 840.0      46188
# 860.0      29740
# 880.0      39284
# 900.0      28497
# 920.0      33990
# 940.0      23509
# 960.0      17196
# 980.0       6685
# 1000.0        55
# Name: NU_NOTA_REDACAO, dtype: int64

# %%
col_FE = MicrodadosENEMSelec['TP_FAIXA_ETARIA']

# %%
col_FE
# Out:
# 0           2
# 1           3
# 2           3
# 3           2
# 4          11
#            ..
# 5513728    11
# 5513729     4
# 5513730     5
# 5513731     5
# 5513732    11
# Name: TP_FAIXA_ETARIA, Length: 5513733, dtype: int64

# %% [markdown]
# **Cria um histograma com as informações de nota da redação(eixo y) e por quantidade de participantes(eixo y)**

# %%
Nota_red.hist(bins=25)
# Out:
# <AxesSubplot: >

# %%
col_UF_prova = MicrodadosENEMSelec['SG_UF_PROVA']

# %%
col_UF_prova.value_counts()
# Out:
# SP    937348
# MG    583031
# BA    398492
# RJ    383247
# CE    328589
# PE    307318
# PA    281807
# RS    243304
# PR    237343
# MA    216757
# GO    190593
# PB    151490
# SC    125361
# RN    124045
# AM    123801
# PI    119377
# ES    111972
# DF    106304
# MT     96793
# AL     87976
# SE     77049
# MS     72393
# RO     61934
# TO     54390
# AP     40622
# AC     38330
# RR     14067
# Name: SG_UF_PROVA, dtype: int64

# %%
coluna_in_treineiro = MicrodadosENEMSelec['IN_TREINEIRO']

# %%
dist_in_treineiro = coluna_in_treineiro.value_counts()

# %%
pecent_in_treineiro = [100*x/dist_in_treineiro.sum()  for x in dist_in_treineiro]

# %%
pecent_in_treineiro
# Out:
# [90.42920649222586, 9.570793507774134]

# %%
coluna_tp_sexo = MicrodadosENEMSelec['TP_SEXO']

# %%
dist_tp_sexo = coluna_tp_sexo.value_counts()

# %%
dist_tp_sexo
# Out:
# F    3257698
# M    2256035
# Name: TP_SEXO, dtype: int64

# %%
pecent_tp_sexo = [100*x/dist_tp_sexo.sum()  for x in dist_tp_sexo]

# %%
pecent_tp_sexo
# Out:
# [59.08334698107435, 40.91665301892565]

# %%
sexo_F = dist_tp_sexo[0]

# %%
treineiro = dist_in_treineiro[1]

# %%
percent_F_treineiro = 100*treineiro/sexo_F

# %%
percent_Nao_F = 100 - percent_F_treineiro

# %%
percent_F_treineiro
# Out:
# 16.198800502686254

# %%
percent_Nao_F
# Out:
# 83.80119949731375
